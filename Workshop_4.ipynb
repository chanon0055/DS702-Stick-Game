# %% [markdown]
# <a href="https://colab.research.google.com/github/chanon0055/DS702-Stick-Game/blob/main/Workshop_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import nessesary libs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
# mount the google drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# upload the dataset.
data = pd.read_csv('/content/drive/MyDrive/DataESWD/placement_data.csv')

# %% [markdown]
# ## Data Understanding
# > read head column to Data Understanding.

# %%
data.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0    120      M   60.8  Central  68.40  Central  Commerce      64.6
# 1    151      M   71.0  Central  58.66  Central   Science      58.0
# 2    178      F   73.0  Central  97.00   Others  Commerce      79.0
# 3     78      M   64.0   Others  80.00   Others   Science      65.0
# 4    164      M   63.0   Others  67.00   Others   Science      64.0
#
#     degree_t workex  etest_p specialisation  mba_p  status  salary
# 0  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000
# 1   Sci&Tech    Yes    56.00        Mkt&Fin  61.30  Placed  690000
# 2  Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000
# 3   Sci&Tech    Yes    69.00        Mkt&Fin  57.65  Placed  500000
# 4   Sci&Tech     No    75.00        Mkt&Fin  66.46  Placed  500000
